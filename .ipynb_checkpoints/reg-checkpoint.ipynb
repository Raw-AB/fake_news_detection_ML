# %%
import pandas as pd
import math  
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("airfoil_self_noise.dat", delim_whitespace=True, names=['Frequency (Hz)','Angle of Attack (deg)','Chord length (m)','Free-stream velocity (m/s)','Suction side displacement thickness (m)', 'Noise (dB)'])
df
# Out:
#       Frequency (Hz)  Angle of Attack (deg)  Chord length (m)  \
# 0                800                    0.0            0.3048
# 1               1000                    0.0            0.3048
# 2               1250                    0.0            0.3048
# 3               1600                    0.0            0.3048
# 4               2000                    0.0            0.3048
# ...              ...                    ...               ...
# 1498            2500                   15.6            0.1016
# 1499            3150                   15.6            0.1016
# 1500            4000                   15.6            0.1016
# 1501            5000                   15.6            0.1016
# 1502            6300                   15.6            0.1016
#
#       Free-stream velocity (m/s)  Suction side displacement thickness (m)  \
# 0                           71.3                                 0.002663
# ...

# %%
plt.figure(figsize=(10, 10))
plot = sns.scatterplot(x= 'Suction side displacement thickness (m)', y='Noise (dB)',data=df,palette="Blues_d").set_title(
    'Suction side displacement thickness/Noise')

plt.show()

# %%
plt.figure(figsize=(10, 10))
plot = sns.scatterplot(x= 'Free-stream velocity (m/s)', y='Suction side displacement thickness (m)',data=df,palette="Blues_d").set_title(
    'Suction side displacement thickness/Free-stream velocity')

plt.show()

# %%
plt.figure(figsize=(10, 10))
plot = sns.scatterplot(x= 'Angle of Attack (deg)', y='Suction side displacement thickness (m)',data=df,palette="Blues_d").set_title(
    'Suction side displacement thickness/Angle of Attack')

plt.show()

# %%
plt.figure(figsize=(10, 10))
plot = sns.scatterplot(x= 'Chord length (m)', y='Suction side displacement thickness (m)',data=df,palette="Blues_d").set_title(
    'Suction side displacement thickness/Chord length')

plt.show()

# %%
plt.figure(figsize=(10, 10))
plot = sns.scatterplot(x= 'Suction side displacement thickness (m)', y='Frequency (Hz)',data=df,palette="Blues_d").set_title(
    'Suction side displacement thickness/Frequency ')

plt.show()

# %%
y = df['Noise (dB)']
X = df.drop('Noise (dB)', axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=40)

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X_train = ss.fit_transform(X_train)
X_test = ss.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=20, random_state=0)

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=20, random_state=0)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn import metrics

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 1.3162566489361711
# Mean Squared Error: 3.2534848938430816
# Root Mean Squared Error: 1.8037419144220943
